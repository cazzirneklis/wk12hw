# %%
import pandas as pd

# %%
pd.read_csv("census.csv")
# Out:
#         state  state fips        commodity  \
# 0    US TOTAL          99  FARM OPERATIONS
# 1    US TOTAL          99  FARM OPERATIONS
# 2    US TOTAL          99  FARM OPERATIONS
# 3    US TOTAL          99  FARM OPERATIONS
# 4    US TOTAL          99  FARM OPERATIONS
# ..        ...         ...              ...
# 124  US TOTAL          99         POTATOES
# 125  US TOTAL          99   SWEET POTATOES
# 126  US TOTAL          99   SWEET POTATOES
# 127  US TOTAL          99         ORCHARDS
# 128  US TOTAL          99         ORCHARDS
#
#                                              data item  \
# 0               FARM OPERATIONS - NUMBER OF OPERATIONS
# 1               FARM OPERATIONS - NUMBER OF OPERATIONS
# 2               FARM OPERATIONS - NUMBER OF OPERATIONS
# 3               FARM OPERATIONS - NUMBER OF OPERATIONS
# 4               FARM OPERATIONS - NUMBER OF OPERATIONS
# ..                                                 ...
# ...

# %%
df=pd.read_csv("census.csv")

# %%
df.head()
# Out:
#        state  state fips          commodity  \
# 0   US TOTAL          99    FARM OPERATIONS
# 1   US TOTAL          99    FARM OPERATIONS
# 2   US TOTAL          99    FARM OPERATIONS
# 3   US TOTAL          99    FARM OPERATIONS
# 4   US TOTAL          99    FARM OPERATIONS
# 5   US TOTAL          99    FARM OPERATIONS
# 6   US TOTAL          99    FARM OPERATIONS
# 7   US TOTAL          99    FARM OPERATIONS
# 8   US TOTAL          99    FARM OPERATIONS
# 9   US TOTAL          99    FARM OPERATIONS
# 10  US TOTAL          99            AG LAND
# 11  US TOTAL          99            AG LAND
# 12  US TOTAL          99   MACHINERY TOTALS
# 13  US TOTAL          99   MACHINERY TOTALS
# 14  US TOTAL          99            AG LAND
# 15  US TOTAL          99            AG LAND
# 16  US TOTAL          99            AG LAND
# 17  US TOTAL          99            AG LAND
# 18  US TOTAL          99            AG LAND
# 19  US TOTAL          99            AG LAND
# ...

# %%
melt_df=df.melt(id_vars=["commodity", "data item"],
              var_name= "domain category", 
             )

# %%
melt_df.sample(50)
# Out:
#               commodity                                          data item  \
# 356              COTTON                           COTTON - ACRES HARVESTED
# 859             SORGHUM    SORGHUM, GRAIN - OPERATIONS WITH AREA HARVESTED
# 893             PEANUTS                          PEANUTS - ACRES HARVESTED
# 743              COTTON                           COTTON - ACRES HARVESTED
# 430            INTEREST                  INTEREST - EXPENSE, MEASURED IN $
# 390     FARM OPERATIONS             FARM OPERATIONS - NUMBER OF OPERATIONS
# 697              CATTLE      CATTLE, INCL CALVES - SALES, MEASURED IN HEAD
# 158    COMMODITY TOTALS           COMMODITY TOTALS - OPERATIONS WITH SALES
# 525     FARM OPERATIONS  FARM OPERATIONS - AREA OPERATED, MEASURED IN A...
# 983                OATS                             OATS - ACRES HARVESTED
# 640            POTATOES                         POTATOES - ACRES HARVESTED
# ...

# %%
melt_df.rename(columns={"domain category":"year"})
# Out:
#             commodity                                          data item  \
# 0     FARM OPERATIONS             FARM OPERATIONS - NUMBER OF OPERATIONS
# 1     FARM OPERATIONS             FARM OPERATIONS - NUMBER OF OPERATIONS
# 2     FARM OPERATIONS             FARM OPERATIONS - NUMBER OF OPERATIONS
# 3     FARM OPERATIONS             FARM OPERATIONS - NUMBER OF OPERATIONS
# 4     FARM OPERATIONS             FARM OPERATIONS - NUMBER OF OPERATIONS
# ...               ...                                                ...
# 1027         POTATOES                         POTATOES - ACRES HARVESTED
# 1028   SWEET POTATOES    SWEET POTATOES - OPERATIONS WITH AREA HARVESTED
# 1029   SWEET POTATOES                   SWEET POTATOES - ACRES HARVESTED
# 1030         ORCHARDS  ORCHARDS - OPERATIONS WITH AREA BEARING & NON-...
# 1031         ORCHARDS             ORCHARDS - ACRES BEARING & NON-BEARING
#
#        year      value
# 0     state   US TOTAL
# 1     state   US TOTAL
# ...
